# %% [markdown]
# Кондрашова Анастасия
# НПМбд-01-19

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import scipy.special as sc

# %% [markdown]
# ## Exercise 1
# 1. Создайте график $x^2⋅sin(1/x^2)+x$ на интервале $[−1,1]$, используя 250 точек. Не забудьте пометить оси!
# 2. Создайте semilogy график (с логарифмической шкалой для оси y и линейной шкалой для оси x) относительной разницы  функций $1/(1+x^2)$ и $1/x^2$ на интервале $[5,25]$. (Относительная разница чисел $a$ и $b$ определяется как $|1−a/b|$)
# 3. В Scipy также есть много менее распространенных специальных функций. Взгляните на обширный список <a href=https://docs.scipy.org/doc/scipy/reference/special.html> здесь</a>! Выберите несколько интересных спец функций, которые вы знаете (или, может быть, не знаете), подставьте несколько чисел и начертите их.

# %%
x = np.linspace(-1, 1,250)
y = x**2*np.sin(1/x**2)+x
plt.plot(x, y, color = 'violet')
plt.xlabel('ось x')
plt.ylabel('ось y')
# Out:
# Text(0, 0.5, 'ось y')

# %%
x = np.linspace(5,25)
y = abs(1-((1/(1+x**2))/(1/x**2)))

fig, ax = plt.subplots()
ax.semilogy(x, y, color = 'violet')
ax.set_xlabel('Ось x')
ax.set_ylabel('Ось y')
ax.set_title('график')
# Out:
# Text(0.5, 1.0, 'график')

# %%
#gamma
x = np.linspace(-3.5, 5.5, 2251)
y = sc.gamma(x)

plt.plot(x, y, 'b', alpha=0.6, color = 'red')
k = np.arange(1, 7)
plt.plot(k, sc.factorial(k-1), 'k*', alpha=0.6,
label='(x-1)!, x = 1, 2, ...')
plt.xlim(-3.5, 5.5)
plt.ylim(-10, 25)
plt.grid()
plt.xlabel('x')
plt.show()

# %%
#diric
x = np.linspace(-8*np.pi, 8*np.pi, num=201)
plt.figure(figsize=(8, 8));
for idx, n in enumerate([2, 3, 4, 9]):
    plt.subplot(2, 2, idx+1)
    plt.plot(x, sc.diric(x, n), color = 'orange')
    plt.title('diric, n={}'.format(n))
plt.show()

# %% [markdown]
# ## Exercise 2
# 1. Построить график функции $sin(x)/x$ на отрезке $[-6\pi;6\pi]$ и добавить тики по оси $x$ с шагом $\pi/2$ от $-6\pi$ до $6\pi$, причём обозначения тиков должны содержать греческую букву $\pi$. Добавить сетку на график.

# %%
x = np.linspace(-6*np.pi, 6*np.pi,24)
y = np.sin(x)/x
fig, ax = plt.subplots(figsize=(16,16))
ax.plot(x, y, color = 'blue')
plt.xticks(
    x,
    [r'$-6\pi$', r'$-5.5\pi$', r'$-5\pi$', r'$-4.5\pi$', r'$-3.5\pi$', r'$-3\pi$', r'$-2.5\pi$',
    r'$-2\pi$', r'$-1.5\pi$', r'$-\pi$', r'$-0.5\pi$', r'0', r'$0.5\pi$', r'$1\pi$', r'$1.5\pi$', r'$2\pi$',
    r'$2.5\pi$', r'$3\pi$', r'$3.5\pi$', r'$4\pi$', r'$4.5\pi$', r'$5\pi$', r'$5.5\pi$', r'$6\pi$',])
ax.set_xlabel('Ось x')
ax.set_ylabel('Ось y')
ax.grid()
ax.set_title('график')
# Out:
# Text(0.5, 1.0, 'график')

# %% [markdown]
# ## Exercise 3
# 1. Создайте цветовой график $sin(x)sin(y)$ на интервале $[−π,π]×[−π,π]$.
# 2. Создайте цветовой график $e^{-x^2-y^2}$ на интервале $[−3,3]×[−3,3]$.

# %%
x = y = np.linspace(-np.pi, np.pi, 100)
X, Y = np.meshgrid(x, y)
fig, ax = plt.subplots()
ax.contourf(X , Y, np.sin(X) * np.sin(Y))

# %%
x = y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)
fig, axs = plt.subplots()
axs.contourf(X , Y, np.exp(- X**2 - Y**2))
